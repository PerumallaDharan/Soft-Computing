# %%
import numpy as np
import pandas as pd

class Perceptron:
    def __init__(self, n_features, alpha=1):
        self.weights = np.zeros(n_features)
        self.bias = 0
        self.alpha = alpha

    def predict(self, X):
        weighted_sum = np.dot(X, self.weights) + self.bias
        return 1 if weighted_sum >= 0 else 0

    def train(self, X, y, n_iter=10):
        for _ in range(n_iter):
            for xi, target in zip(X, y):
                prediction = self.predict(xi)
                if prediction != target:  # Only update if the prediction is incorrect
                    update = self.alpha * (target - prediction)
                    self.weights += update * xi
                    self.bias += update
                    print(f"Current Epoch : {_} \nUpdated Weights: {self.weights}\nBias: {self.bias}",end = '\n\n')

def load_csv_data(file_path, target_column):
    df = pd.read_csv(file_path)
    X = df.drop(target_column, axis=1).values  # Features
    y = df[target_column].values               # Target
    return X, y

def calculate_accuracy(perceptron, X, y):
    correct_predictions = sum(perceptron.predict(xi) == target for xi, target in zip(X, y))
    accuracy = correct_predictions / len(y)
    return accuracy

# Example usage:
if __name__ == "__main__":
    file_path = "random_data.csv"
    target_column = "result" 
    X, y = load_csv_data(file_path, target_column)

    # Initialize the Perceptron with the correct number of features
    perceptron = Perceptron(n_features=X.shape[1])

    # Train the Perceptron
    perceptron.train(X, y, n_iter=10)

    # Print the final weights and bias
    print("Final Weights:", perceptron.weights)
    print("Final Bias:", perceptron.bias)

    # Ensure the input has the correct number of features
    prediction_input = [33, 34, 56, 98, 50, 92, 1]  # Adjust as needed

    prediction = perceptron.predict(prediction_input)
    print(f"Prediction for {prediction_input}: {prediction}")

    # Calculate and print the accuracy
    accuracy = calculate_accuracy(perceptron, X, y)
    print(f"Accuracy: {accuracy * 100:.2f}%")
# Out:
# Current Epoch : 0
# Updated Weights: [ -2. -81.  -9.  -8. -35. -82. -31.]
# Bias: -1
#
# Current Epoch : 0
# Updated Weights: [  4.  -8.  54.  58.  21. -48.  45.]
# Bias: 0
#
# Current Epoch : 0
# Updated Weights: [ -3.  -8.  17.  46. -20. -67.  29.]
# Bias: -1
#
# Current Epoch : 0
# Updated Weights: [ 5. 70. 34. 93. 66. 12. 55.]
# Bias: 0
#
# Current Epoch : 1
# Updated Weights: [  3. -11.  25.  85.  31. -70.  24.]
# Bias: -1
#
# Current Epoch : 1
# Updated Weights: [  0. -19.  20.  54. -18. -91.   7.]
# Bias: -2
#
# Current Epoch : 1
# Updated Weights: [ -5. -72. -48. -41. -68. -99.   3.]
# Bias: -3
#
# Current Epoch : 1
# Updated Weights: [  1.   1.  15.  25. -12. -65.  79.]
# Bias: -2
#
# Current Epoch : 1
# Updated Weights: [ -6.   1. -22.  13. -53. -84.  63.]
# Bias: -3
#
# Current Epoch : 1
# Updated Weights: [ 2. 79. -5. 60. 33. -5. 89.]
# Bias: -2
#
# Current Epoch : 2
# Updated Weights: [  0.  -2. -14.  52.  -2. -87.  58.]
# Bias: -3
#
# Current Epoch : 2
# Updated Weights: [  -3.  -10.  -19.   21.  -51. -108.   41.]
# Bias: -4
#
# Current Epoch : 2
# Updated Weights: [  3.  63.  44.  87.   5. -74. 117.]
# Bias: -3
#
# Current Epoch : 2
# Updated Weights: [ -4.  63.   7.  75. -36. -93. 101.]
# Bias: -4
#
# Current Epoch : 2
# Updated Weights: [  6.  84.  56. 142.  57. -13. 133.]
# Bias: -3
#
# Current Epoch : 3
# Updated Weights: [  4.   3.  47. 134.  22. -95. 102.]
# Bias: -4
#
# Current Epoch : 3
# Updated Weights: [   1.   -5.   42.  103.  -27. -116.   85.]
# Bias: -5
#
# Current Epoch : 3
# Updated Weights: [  -3.  -85.   -5.   78.  -64. -143.   29.]
# Bias: -6
#
# Current Epoch : 3
# Updated Weights: [   3.  -12.   58.  144.   -8. -109.  105.]
# Bias: -5
#
# Current Epoch : 3
# Updated Weights: [  -4.  -12.   21.  132.  -49. -128.   89.]
# Bias: -6
#
# Current Epoch : 3
# Updated Weights: [  4.  66.  38. 179.  37. -49. 115.]
# Bias: -5
#
# Current Epoch : 4
# Updated Weights: [   2.  -15.   29.  171.    2. -131.   84.]
# Bias: -6
#
# Current Epoch : 4
# Updated Weights: [  -1.  -23.   24.  140.  -47. -152.   67.]
# Bias: -7
#
# Current Epoch : 4
# Updated Weights: [  -5. -103.  -23.  115.  -84. -179.   11.]
# Bias: -8
#
# Current Epoch : 4
# Updated Weights: [   1.  -30.   40.  181.  -28. -145.   87.]
# Bias: -7
#
# Current Epoch : 4
# Updated Weights: [  -6.  -30.    3.  169.  -69. -164.   71.]
# Bias: -8
#
# Current Epoch : 4
# Updated Weights: [  2.  48.  20. 216.  17. -85.  97.]
# Bias: -7
#
# Current Epoch : 5
# Updated Weights: [   0.  -33.   11.  208.  -18. -167.   66.]
# Bias: -8
#
# Current Epoch : 5
# Updated Weights: [  -3.  -41.    6.  177.  -67. -188.   49.]
# Bias: -9
#
# Current Epoch : 5
# Updated Weights: [  -8.  -94.  -62.   82. -117. -196.   45.]
# Bias: -10
#
# Current Epoch : 5
# Updated Weights: [  -2.  -21.    1.  148.  -61. -162.  121.]
# Bias: -9
#
# Current Epoch : 5
# Updated Weights: [  6.  57.  18. 195.  25. -83. 147.]
# Bias: -8
#
# Current Epoch : 6
# Updated Weights: [   4.  -24.    9.  187.  -10. -165.  116.]
# Bias: -9
#
# Current Epoch : 6
# Updated Weights: [   1.  -32.    4.  156.  -59. -186.   99.]
# Bias: -10
#
# Current Epoch : 6
# Updated Weights: [  -4.  -85.  -64.   61. -109. -194.   95.]
# Bias: -11
#
# Current Epoch : 6
# Updated Weights: [   2.  -12.   -1.  127.  -53. -160.  171.]
# Bias: -10
#
# Current Epoch : 6
# Updated Weights: [ 10.  66.  16. 174.  33. -81. 197.]
# Bias: -9
#
# Current Epoch : 7
# Updated Weights: [   8.  -15.    7.  166.   -2. -163.  166.]
# Bias: -10
#
# Current Epoch : 7
# Updated Weights: [   5.  -23.    2.  135.  -51. -184.  149.]
# Bias: -11
#
# Current Epoch : 7
# Updated Weights: [   1. -103.  -45.  110.  -88. -211.   93.]
# Bias: -12
#
# Current Epoch : 7
# Updated Weights: [   7.  -30.   18.  176.  -32. -177.  169.]
# Bias: -11
#
# Current Epoch : 7
# Updated Weights: [   0.  -30.  -19.  164.  -73. -196.  153.]
# Bias: -12
#
# Current Epoch : 7
# Updated Weights: [   8.   48.   -2.  211.   13. -117.  179.]
# Bias: -11
#
# Current Epoch : 8
# Updated Weights: [   6.  -33.  -11.  203.  -22. -199.  148.]
# Bias: -12
#
# Current Epoch : 8
# Updated Weights: [   3.  -41.  -16.  172.  -71. -220.  131.]
# Bias: -13
#
# Current Epoch : 8
# Updated Weights: [  -2.  -94.  -84.   77. -121. -228.  127.]
# Bias: -14
#
# Current Epoch : 8
# Updated Weights: [   4.  -21.  -21.  143.  -65. -194.  203.]
# Bias: -13
#
# Current Epoch : 8
# Updated Weights: [  12.   57.   -4.  190.   21. -115.  229.]
# Bias: -12
#
# Current Epoch : 9
# Updated Weights: [  10.  -24.  -13.  182.  -14. -197.  198.]
# Bias: -13
#
# Current Epoch : 9
# Updated Weights: [   7.  -32.  -18.  151.  -63. -218.  181.]
# Bias: -14
#
# Current Epoch : 9
# Updated Weights: [   3. -112.  -65.  126. -100. -245.  125.]
# Bias: -15
#
# Current Epoch : 9
# Updated Weights: [   9.  -39.   -2.  192.  -44. -211.  201.]
# Bias: -14
#
# Current Epoch : 9
# Updated Weights: [  17.   39.   15.  239.   42. -132.  227.]
# Bias: -13
#
# Final Weights: [  17.   39.   15.  239.   42. -132.  227.]
# Final Bias: -13
# Prediction for [33, 34, 56, 98, 50, 92, 1]: 1
# Accuracy: 50.00%

# %%
import numpy as np
import pandas as pd

class Perceptron:
    def __init__(self, input_size, learning_rate=1, iterations=10):
        self.weights = np.zeros(input_size + 1)
        self.learning_rate = learning_rate
        self.iterations = iterations

    def activation_function(self, x):
        return 1 if x >= 0 else 0

    def predict(self, x):
        z = np.dot(x, self.weights[1:]) + self.weights[0]
        return self.activation_function(z)

    def train(self, X, y):
        for _ in range(self.iterations):
            for xi, target in zip(X, y):
                prediction = self.predict(xi)
                if prediction!=target:
                    self.weights[1:] += self.learning_rate * (target ) * xi
                    self.weights[0] += self.learning_rate * (target )
                    print(f"Current Epoch : {_} \nUpdated Weights: {self.weights}\nBias: {self.weights[0]}",end = '\n\n')

    def evaluate(self, X, y):
        predictions = [self.predict(xi) for xi in X]
        accuracy = np.mean(predictions == y)
        return accuracy

df = pd.read_csv('random_data.csv')

X = df[['c1', 'c2', 'c3', 'c4', 'c5', 'c6']].values
y = df['result'].values

perceptron = Perceptron(input_size=X.shape[1], learning_rate=0.01, iterations=1000)

perceptron.train(X, y)
accuracy = perceptron.evaluate(X, y)
print(f"Training accuracy: {accuracy * 100:.2f}%")

new_marks = np.array([70, 80, 65, 75, 60, 85]) 
prediction = perceptron.predict(new_marks)
print(f"Prediction for new marks (Pass=1, Fail=0): {prediction}")
# Out:
# Current Epoch : 0
# Updated Weights: [0. 0. 0. 0. 0. 0. 0.]
# Bias: 0.0
#
# Current Epoch : 0
# Updated Weights: [0. 0. 0. 0. 0. 0. 0.]
# Bias: 0.0
#
# Current Epoch : 0
# Updated Weights: [0. 0. 0. 0. 0. 0. 0.]
# Bias: 0.0
#
# Current Epoch : 0
# Updated Weights: [0. 0. 0. 0. 0. 0. 0.]
# Bias: 0.0
#
# Current Epoch : 0
# Updated Weights: [0. 0. 0. 0. 0. 0. 0.]
# Bias: 0.0
#
# Current Epoch : 1
# Updated Weights: [0. 0. 0. 0. 0. 0. 0.]
# Bias: 0.0
#
# Current Epoch : 1
# Updated Weights: [0. 0. 0. 0. 0. 0. 0.]
# Bias: 0.0
#
# Current Epoch : 1
# Updated Weights: [0. 0. 0. 0. 0. 0. 0.]
# Bias: 0.0
#
# Current Epoch : 1
# Updated Weights: [0. 0. 0. 0. 0. 0. 0.]
# Bias: 0.0
#
# Current Epoch : 1
# Updated Weights: [0. 0. 0. 0. 0. 0. 0.]
# Bias: 0.0
#
# Current Epoch : 2
# Updated Weights: [0. 0. 0. 0. 0. 0. 0.]
# Bias: 0.0
#
# Current Epoch : 2
# Updated Weights: [0. 0. 0. 0. 0. 0. 0.]
# Bias: 0.0
#
# Current Epoch : 2
# Updated Weights: [0. 0. 0. 0. 0. 0. 0.]
# Bias: 0.0
#
# Current Epoch : 2
# Updated Weights: [0. 0. 0. 0. 0. 0. 0.]
# Bias: 0.0
#
# Current Epoch : 2
# Updated Weights: [0. 0. 0. 0. 0. 0. 0.]
# Bias: 0.0
#
# Current Epoch : 3
# Updated Weights: [0. 0. 0. 0. 0. 0. 0.]
# Bias: 0.0
#
# Current Epoch : 3
# Updated Weights: [0. 0. 0. 0. 0. 0. 0.]
# Bias: 0.0
#
# Current Epoch : 3
# Updated Weights: [0. 0. 0. 0. 0. 0. 0.]
# Bias: 0.0
#
# Current Epoch : 3
# Updated Weights: [0. 0. 0. 0. 0. 0. 0.]
# Bias: 0.0
#
# Current Epoch : 3
# Updated Weights: [0. 0. 0. 0. 0. 0. 0.]
# Bias: 0.0
#
# Current Epoch : 4
# Updated Weights: [0. 0. 0. 0. 0. 0. 0.]
# Bias: 0.0
#
# Current Epoch : 4
# Updated Weights: [0. 0. 0. 0. 0. 0. 0.]
# Bias: 0.0
#
# Current Epoch : 4
# Updated Weights: [0. 0. 0. 0. 0. 0. 0.]
# Bias: 0.0
#
# Current Epoch : 4
# Updated Weights: [0. 0. 0. 0. 0. 0. 0.]
# Bias: 0.0
#
# Current Epoch : 4
# Updated Weights: [0. 0. 0. 0. 0. 0. 0.]
# Bias: 0.0
#
# Current Epoch : 5
# Updated Weights: [0. 0. 0. 0. 0. 0. 0.]
# Bias: 0.0
#
# Current Epoch : 5
# Updated Weights: [0. 0. 0. 0. 0. 0. 0.]
# Bias: 0.0
#
# Current Epoch : 5
# Updated Weights: [0. 0. 0. 0. 0. 0. 0.]
# Bias: 0.0
#
# Current Epoch : 5
# Updated Weights: [0. 0. 0. 0. 0. 0. 0.]
# Bias: 0.0
#
# Current Epoch : 5
# Updated Weights: [0. 0. 0. 0. 0. 0. 0.]
# Bias: 0.0
#
# Current Epoch : 6
# Updated Weights: [0. 0. 0. 0. 0. 0. 0.]
# Bias: 0.0
#
# Current Epoch : 6
# Updated Weights: [0. 0. 0. 0. 0. 0. 0.]
# Bias: 0.0
#
# Current Epoch : 6
# Updated Weights: [0. 0. 0. 0. 0. 0. 0.]
# Bias: 0.0
#
# Current Epoch : 6
# Updated Weights: [0. 0. 0. 0. 0. 0. 0.]
# Bias: 0.0
#
# Current Epoch : 6
# Updated Weights: [0. 0. 0. 0. 0. 0. 0.]
# Bias: 0.0
#
# Current Epoch : 7
# Updated Weights: [0. 0. 0. 0. 0. 0. 0.]
# Bias: 0.0
#
# Current Epoch : 7
# Updated Weights: [0. 0. 0. 0. 0. 0. 0.]
# Bias: 0.0
#
# Current Epoch : 7
# Updated Weights: [0. 0. 0. 0. 0. 0. 0.]
# Bias: 0.0
#
# Current Epoch : 7
# Updated Weights: [0. 0. 0. 0. 0. 0. 0.]
# Bias: 0.0
#
# Current Epoch : 7
# Updated Weights: [0. 0. 0. 0. 0. 0. 0.]
# Bias: 0.0
#
# Current Epoch : 8
# Updated Weights: [0. 0. 0. 0. 0. 0. 0.]
# Bias: 0.0
#
# Current Epoch : 8
# Updated Weights: [0. 0. 0. 0. 0. 0. 0.]
# Bias: 0.0
#
# Current Epoch : 8
# Updated Weights: [0. 0. 0. 0. 0. 0. 0.]
# Bias: 0.0
#
# Current Epoch : 8
# Updated Weights: [0. 0. 0. 0. 0. 0. 0.]
# Bias: 0.0
#
# Current Epoch : 8
# Updated Weights: [0. 0. 0. 0. 0. 0. 0.]
# Bias: 0.0
#
# Current Epoch : 9
# Updated Weights: [0. 0. 0. 0. 0. 0. 0.]
# Bias: 0.0
#
# Current Epoch : 9
# Updated Weights: [0. 0. 0. 0. 0. 0. 0.]
# Bias: 0.0
#
# Current Epoch : 9
# Updated Weights: [0. 0. 0. 0. 0. 0. 0.]
# Bias: 0.0
#
# Current Epoch : 9
# Updated Weights: [0. 0. 0. 0. 0. 0. 0.]
# Bias: 0.0
#
# Current Epoch : 9
# Updated Weights: [0. 0. 0. 0. 0. 0. 0.]
# Bias: 0.0
#
# Current Epoch : 10
# Updated Weights: [0. 0. 0. 0. 0. 0. 0.]
# Bias: 0.0
#
# Current Epoch : 10
# Updated Weights: [0. 0. 0. 0. 0. 0. 0.]
# Bias: 0.0
#
# Current Epoch : 10
# Updated Weights: [0. 0. 0. 0. 0. 0. 0.]
# Bias: 0.0
#
# Current Epoch : 10
# Updated Weights: [0. 0. 0. 0. 0. 0. 0.]
# Bias: 0.0
#
# Current Epoch : 10
# Updated Weights: [0. 0. 0. 0. 0. 0. 0.]
# Bias: 0.0
#
# Current Epoch : 11
# Updated Weights: [0. 0. 0. 0. 0. 0. 0.]
# Bias: 0.0
#
# Current Epoch : 11
# Updated Weights: [0. 0. 0. 0. 0. 0. 0.]
# Bias: 0.0
#
# Current Epoch : 11
# Updated Weights: [0. 0. 0. 0. 0. 0. 0.]
# Bias: 0.0
#
# Current Epoch : 11
# Updated Weights: [0. 0. 0. 0. 0. 0. 0.]
# Bias: 0.0
#
# Current Epoch : 11
# Updated Weights: [0. 0. 0. 0. 0. 0. 0.]
# Bias: 0.0
#
# Current Epoch : 12
# Updated Weights: [0. 0. 0. 0. 0. 0. 0.]
# Bias: 0.0
#
# Current Epoch : 12
# Updated Weights: [0. 0. 0. 0. 0. 0. 0.]
# Bias: 0.0
#
# Current Epoch : 12
# Updated Weights: [0. 0. 0. 0. 0. 0. 0.]
# Bias: 0.0
#
# Current Epoch : 12
# Updated Weights: [0. 0. 0. 0. 0. 0. 0.]
# Bias: 0.0
#
# Current Epoch : 12
# Updated Weights: [0. 0. 0. 0. 0. 0. 0.]
# Bias: 0.0
#
# Current Epoch : 13
# Updated Weights: [0. 0. 0. 0. 0. 0. 0.]
# Bias: 0.0
#
# Current Epoch : 13
# Updated Weights: [0. 0. 0. 0. 0. 0. 0.]
# Bias: 0.0
#
# Current Epoch : 13
# Updated Weights: [0. 0. 0. 0. 0. 0. 0.]
# Bias: 0.0
#
# Current Epoch : 13
# Updated Weights: [0. 0. 0. 0. 0. 0. 0.]
# Bias: 0.0
#
# Current Epoch : 13
# Updated Weights: [0. 0. 0. 0. 0. 0. 0.]
# Bias: 0.0
#
# Current Epoch : 14
# Updated Weights: [0. 0. 0. 0. 0. 0. 0.]
# Bias: 0.0
#
# Current Epoch : 14
# Updated Weights: [0. 0. 0. 0. 0. 0. 0.]
# Bias: 0.0
#
# Current Epoch : 14
# Updated Weights: [0. 0. 0. 0. 0. 0. 0.]
# Bias: 0.0
#
# Current Epoch : 14
# Updated Weights: [0. 0. 0. 0. 0. 0. 0.]
# Bias: 0.0
#
# Current Epoch : 14
# Updated Weights: [0. 0. 0. 0. 0. 0. 0.]
# Bias: 0.0
#
# Current Epoch : 15
# Updated Weights: [0. 0. 0. 0. 0. 0. 0.]
# Bias: 0.0
#
# Current Epoch : 15
# Updated Weights: [0. 0. 0. 0. 0. 0. 0.]
# Bias: 0.0
#
# Current Epoch : 15
# Updated Weights: [0. 0. 0. 0. 0. 0. 0.]
# Bias: 0.0
#
# Current Epoch : 15
# Updated Weights: [0. 0. 0. 0. 0. 0. 0.]
# Bias: 0.0
#
# Current Epoch : 15
# Updated Weights: [0. 0. 0. 0. 0. 0. 0.]
# Bias: 0.0
#
# Current Epoch : 16
# Updated Weights: [0. 0. 0. 0. 0. 0. 0.]
# Bias: 0.0
#
# Current Epoch : 16
# Updated Weights: [0. 0. 0. 0. 0. 0. 0.]
# Bias: 0.0
#
# Current Epoch : 16
# Updated Weights: [0. 0. 0. 0. 0. 0. 0.]
# Bias: 0.0
#
# Current Epoch : 16
# Updated Weights: [0. 0. 0. 0. 0. 0. 0.]
# Bias: 0.0
#
# Current Epoch : 16
# Updated Weights: [0. 0. 0. 0. 0. 0. 0.]
# Bias: 0.0
#
# Current Epoch : 17
# Updated Weights: [0. 0. 0. 0. 0. 0. 0.]
# Bias: 0.0
#
# Current Epoch : 17
# Updated Weights: [0. 0. 0. 0. 0. 0. 0.]
# Bias: 0.0
#
# Current Epoch : 17
# Updated Weights: [0. 0. 0. 0. 0. 0. 0.]
# Bias: 0.0
#
# Current Epoch : 17
# Updated Weights: [0. 0. 0. 0. 0. 0. 0.]
# Bias: 0.0
#
# Current Epoch : 17
# Updated Weights: [0. 0. 0. 0. 0. 0. 0.]
# Bias: 0.0
#
# Current Epoch : 18
# Updated Weights: [0. 0. 0. 0. 0. 0. 0.]
# Bias: 0.0
#
# Current Epoch : 18
# Updated Weights: [0. 0. 0. 0. 0. 0. 0.]
# Bias: 0.0
#
# Current Epoch : 18
# Updated Weights: [0. 0. 0. 0. 0. 0. 0.]
# Bias: 0.0
#
# Current Epoch : 18
# Updated Weights: [0. 0. 0. 0. 0. 0. 0.]
# Bias: 0.0
#
# Current Epoch : 18
# Updated Weights: [0. 0. 0. 0. 0. 0. 0.]
# Bias: 0.0
#
# Current Epoch : 19
# Updated Weights: [0. 0. 0. 0. 0. 0. 0.]
# Bias: 0.0
#
# Current Epoch : 19
# Updated Weights: [0. 0. 0. 0. 0. 0. 0.]
# Bias: 0.0
#
# Current Epoch : 19
# Updated Weights: [0. 0. 0. 0. 0. 0. 0.]
# Bias: 0.0
#
# Current Epoch : 19
# Updated Weights: [0. 0. 0. 0. 0. 0. 0.]
# Bias: 0.0
#
# Current Epoch : 19
# Updated Weights: [0. 0. 0. 0. 0. 0. 0.]
# Bias: 0.0
#
# Current Epoch : 20
# Updated Weights: [0. 0. 0. 0. 0. 0. 0.]
# Bias: 0.0
#
# Current Epoch : 20
# Updated Weights: [0. 0. 0. 0. 0. 0. 0.]
# Bias: 0.0
#
# Current Epoch : 20
# Updated Weights: [0. 0. 0. 0. 0. 0. 0.]
# Bias: 0.0
#
# Current Epoch : 20
# Updated Weights: [0. 0. 0. 0. 0. 0. 0.]
# Bias: 0.0
#
# Current Epoch : 20
# Updated Weights: [0. 0. 0. 0. 0. 0. 0.]
# Bias: 0.0
#
# Current Epoch : 21
# Updated Weights: [0. 0. 0. 0. 0. 0. 0.]
# Bias: 0.0
#
# Current Epoch : 21
# Updated Weights: [0. 0. 0. 0. 0. 0. 0.]
# Bias: 0.0
#
# Current Epoch : 21
# Updated Weights: [0. 0. 0. 0. 0. 0. 0.]
# Bias: 0.0
#
# Current Epoch :