# %%
import numpy as np
import pandas as pd

class Perceptron:
    def __init__(self, input_size, learning_rate=0.1, epochs=10):
        self.weights = np.zeros(input_size + 1)  # +1 for the bias term
        self.learning_rate = learning_rate
        self.epochs = epochs

    def activation_function(self, x):
        return 1 if x >= 0 else 0

    def predict(self, x):
        z = np.dot(x, self.weights[1:]) + self.weights[0]
        return self.activation_function(z)

    def train(self, X, y):
        for epoch in range(self.epochs):
            print(f"\nEpoch {epoch + 1}/{self.epochs}")
            for xi, target in zip(X, y):
                prediction = self.predict(xi)
                # print(f"weights:{self.weights}")
                if prediction != target:
                    # Update weights and bias
                    self.weights[1:] += self.learning_rate * (target - prediction) * xi
                    self.weights[0] += self.learning_rate * (target - prediction)
                    print(f"Sample: {xi}")
                    print(f"Prediction: {prediction}, Target: {target}")
                    print(f"Updated weights: {self.weights}")
                    print(f"Updated bias: {self.weights[0]}")

    def evaluate(self, X, y):
        predictions = np.array([self.predict(xi) for xi in X])
        accuracy = np.mean(predictions == y)
        return accuracy

# Load the data from CSV file
df = pd.read_csv('random_data.csv')

# Extract features (marks) and target labels (result)
X = df[['c1', 'c2', 'c3', 'c4', 'c5', 'c6']].values
y = df['result'].values

# Initialize the Perceptron
perceptron = Perceptron(input_size=X.shape[1], learning_rate=0.1, epochs=10)

# Train the Perceptron
perceptron.train(X, y)

# Evaluate the Perceptron
accuracy = perceptron.evaluate(X, y)
print(f"\nTraining accuracy: {accuracy * 100:.2f}%")

# Predict for a new set of marks
new_marks = np.array([70, 80, 65, 75, 60, 85])  # Example new marks
prediction = perceptron.predict(new_marks)
print(f"Prediction for new marks (Pass=1, Fail=0): {prediction}")
# Out:
# Epoch 1/10
# Sample: [81  9  8 35 82 31]
# Prediction: 1, Target: 0
# Updated weights: [-0.1 -8.1 -0.9 -0.8 -3.5 -8.2 -3.1]
# Updated bias: -0.1
# Sample: [73 63 66 56 34 76]
# Prediction: 0, Target: 1
# Updated weights: [ 0.  -0.8  5.4  5.8  2.1 -4.8  4.5]
# Updated bias: 0.0
# Sample: [ 0 37 12 41 19 16]
# Prediction: 1, Target: 0
# Updated weights: [-0.1 -0.8  1.7  4.6 -2.  -6.7  2.9]
# Updated bias: -0.1
# Sample: [78 17 47 86 79 26]
# Prediction: 0, Target: 1
# Updated weights: [0.  7.  3.4 9.3 6.6 1.2 5.5]
# Updated bias: 0.0
#
# Epoch 2/10
# Sample: [81  9  8 35 82 31]
# Prediction: 1, Target: 0
# Updated weights: [-0.1 -1.1  2.5  8.5  3.1 -7.   2.4]
# Updated bias: -0.1
# Sample: [ 8  5 31 49 21 17]
# Prediction: 1, Target: 0
# Updated weights: [-0.2 -1.9  2.   5.4 -1.8 -9.1  0.7]
# Updated bias: -0.2
# Sample: [53 68 95 50  8  4]
# Prediction: 1, Target: 0
# Updated weights: [-0.3 -7.2 -4.8 -4.1 -6.8 -9.9  0.3]
# Updated bias: -0.30000000000000004
# Sample: [73 63 66 56 34 76]
# Prediction: 0, Target: 1
# Updated weights: [-0.2  0.1  1.5  2.5 -1.2 -6.5  7.9]
# Updated bias: -0.20000000000000004
# Sample: [ 0 37 12 41 19 16]
# Prediction: 1, Target: 0
# Updated weights: [-0.3  0.1 -2.2  1.3 -5.3 -8.4  6.3]
# Updated bias: -0.30000000000000004
# Sample: [78 17 47 86 79 26]
# Prediction: 0, Target: 1
# Updated weights: [-0.2  7.9 -0.5  6.   3.3 -0.5  8.9]
# Updated bias: -0.20000000000000004
#
# Epoch 3/10
# Sample: [81  9  8 35 82 31]
# Prediction: 1, Target: 0
# Updated weights: [-0.3 -0.2 -1.4  5.2 -0.2 -8.7  5.8]
# Updated bias: -0.30000000000000004
# Sample: [ 8  5 31 49 21 17]
# Prediction: 1, Target: 0
# Updated weights: [ -0.4  -1.   -1.9   2.1  -5.1 -10.8   4.1]
# Updated bias: -0.4
# Sample: [73 63 66 56 34 76]
# Prediction: 0, Target: 1
# Updated weights: [-0.3  6.3  4.4  8.7  0.5 -7.4 11.7]
# Updated bias: -0.30000000000000004
# Sample: [ 0 37 12 41 19 16]
# Prediction: 1, Target: 0
# Updated weights: [-0.4  6.3  0.7  7.5 -3.6 -9.3 10.1]
# Updated bias: -0.4
# Sample: [21 49 67 93 80 32]
# Prediction: 0, Target: 1
# Updated weights: [-0.3  8.4  5.6 14.2  5.7 -1.3 13.3]
# Updated bias: -0.30000000000000004
#
# Epoch 4/10
# Sample: [81  9  8 35 82 31]
# Prediction: 1, Target: 0
# Updated weights: [-0.4  0.3  4.7 13.4  2.2 -9.5 10.2]
# Updated bias: -0.4
# Sample: [ 8  5 31 49 21 17]
# Prediction: 1, Target: 0
# Updated weights: [ -0.5  -0.5   4.2  10.3  -2.7 -11.6   8.5]
# Updated bias: -0.5
# Sample: [80 47 25 37 27 56]
# Prediction: 1, Target: 0
# Updated weights: [ -0.6  -8.5  -0.5   7.8  -6.4 -14.3   2.9]
# Updated bias: -0.6
# Sample: [73 63 66 56 34 76]
# Prediction: 0, Target: 1
# Updated weights: [ -0.5  -1.2   5.8  14.4  -0.8 -10.9  10.5]
# Updated bias: -0.5
# Sample: [ 0 37 12 41 19 16]
# Prediction: 1, Target: 0
# Updated weights: [ -0.6  -1.2   2.1  13.2  -4.9 -12.8   8.9]
# Updated bias: -0.6
# Sample: [78 17 47 86 79 26]
# Prediction: 0, Target: 1
# Updated weights: [-0.5  6.6  3.8 17.9  3.7 -4.9 11.5]
# Updated bias: -0.5
#
# Epoch 5/10
# Sample: [81  9  8 35 82 31]
# Prediction: 1, Target: 0
# Updated weights: [ -0.6  -1.5   2.9  17.1   0.2 -13.1   8.4]
# Updated bias: -0.6
# Sample: [ 8  5 31 49 21 17]
# Prediction: 1, Target: 0
# Updated weights: [ -0.7  -2.3   2.4  14.   -4.7 -15.2   6.7]
# Updated bias: -0.7
# Sample: [80 47 25 37 27 56]
# Prediction: 1, Target: 0
# Updated weights: [ -0.8 -10.3  -2.3  11.5  -8.4 -17.9   1.1]
# Updated bias: -0.7999999999999999
# Sample: [73 63 66 56 34 76]
# Prediction: 0, Target: 1
# Updated weights: [ -0.7  -3.    4.   18.1  -2.8 -14.5   8.7]
# Updated bias: -0.7
# Sample: [ 0 37 12 41 19 16]
# Prediction: 1, Target: 0
# Updated weights: [ -0.8  -3.    0.3  16.9  -6.9 -16.4   7.1]
# Updated bias: -0.7999999999999999
# Sample: [78 17 47 86 79 26]
# Prediction: 0, Target: 1
# Updated weights: [-0.7  4.8  2.  21.6  1.7 -8.5  9.7]
# Updated bias: -0.7
#
# Epoch 6/10
# Sample: [81  9  8 35 82 31]
# Prediction: 1, Target: 0
# Updated weights: [ -0.8  -3.3   1.1  20.8  -1.8 -16.7   6.6]
# Updated bias: -0.7999999999999999
# Sample: [ 8  5 31 49 21 17]
# Prediction: 1, Target: 0
# Updated weights: [ -0.9  -4.1   0.6  17.7  -6.7 -18.8   4.9]
# Updated bias: -0.8999999999999999
# Sample: [53 68 95 50  8  4]
# Prediction: 1, Target: 0
# Updated weights: [ -1.   -9.4  -6.2   8.2 -11.7 -19.6   4.5]
# Updated bias: -0.9999999999999999
# Sample: [73 63 66 56 34 76]
# Prediction: 0, Target: 1
# Updated weights: [ -0.9  -2.1   0.1  14.8  -6.1 -16.2  12.1]
# Updated bias: -0.8999999999999999
# Sample: [78 17 47 86 79 26]
# Prediction: 0, Target: 1
# Updated weights: [-0.8  5.7  1.8 19.5  2.5 -8.3 14.7]
# Updated bias: -0.7999999999999999
#
# Epoch 7/10
# Sample: [81  9  8 35 82 31]
# Prediction: 1, Target: 0
# Updated weights: [ -0.9  -2.4   0.9  18.7  -1.  -16.5  11.6]
# Updated bias: -0.8999999999999999
# Sample: [ 8  5 31 49 21 17]
# Prediction: 1, Target: 0
# Updated weights: [ -1.   -3.2   0.4  15.6  -5.9 -18.6   9.9]
# Updated bias: -0.9999999999999999
# Sample: [53 68 95 50  8  4]
# Prediction: 1, Target: 0
# Updated weights: [ -1.1  -8.5  -6.4   6.1 -10.9 -19.4   9.5]
# Updated bias: -1.0999999999999999
# Sample: [73 63 66 56 34 76]
# Prediction: 0, Target: 1
# Updated weights: [ -1.   -1.2  -0.1  12.7  -5.3 -16.   17.1]
# Updated bias: -0.9999999999999999
# Sample: [78 17 47 86 79 26]
# Prediction: 0, Target: 1
# Updated weights: [-0.9  6.6  1.6 17.4  3.3 -8.1 19.7]
# Updated bias: -0.8999999999999999
#
# Epoch 8/10
# Sample: [81  9  8 35 82 31]
# Prediction: 1, Target: 0
# Updated weights: [ -1.   -1.5   0.7  16.6  -0.2 -16.3  16.6]
# Updated bias: -0.9999999999999999
# Sample: [ 8  5 31 49 21 17]
# Prediction: 1, Target: 0
# Updated weights: [ -1.1  -2.3   0.2  13.5  -5.1 -18.4  14.9]
# Updated bias: -1.0999999999999999
# Sample: [80 47 25 37 27 56]
# Prediction: 1, Target: 0
# Updated weights: [ -1.2 -10.3  -4.5  11.   -8.8 -21.1   9.3]
# Updated bias: -1.2
# Sample: [73 63 66 56 34 76]
# Prediction: 0, Target: 1
# Updated weights: [ -1.1  -3.    1.8  17.6  -3.2 -17.7  16.9]
# Updated bias: -1.0999999999999999
# Sample: [ 0 37 12 41 19 16]
# Prediction: 1, Target: 0
# Updated weights: [ -1.2  -3.   -1.9  16.4  -7.3 -19.6  15.3]
# Updated bias: -1.2
# Sample: [78 17 47 86 79 26]
# Prediction: 0, Target: 1
# Updated weights: [ -1.1   4.8  -0.2  21.1   1.3 -11.7  17.9]
# Updated bias: -1.0999999999999999
#
# Epoch 9/10
# Sample: [81  9  8 35 82 31]
# Prediction: 1, Target: 0
# Updated weights: [ -1.2  -3.3  -1.1  20.3  -2.2 -19.9  14.8]
# Updated bias: -1.2
# Sample: [ 8  5 31 49 21 17]
# Prediction: 1, Target: 0
# Updated weights: [ -1.3  -4.1  -1.6  17.2  -7.1 -22.   13.1]
# Updated bias: -1.3
# Sample: [53 68 95 50  8  4]
# Prediction: 1, Target: 0
# Updated weights: [ -1.4  -9.4  -8.4   7.7 -12.1 -22.8  12.7]
# Updated bias: -1.4000000000000001
# Sample: [73 63 66 56 34 76]
# Prediction: 0, Target: 1
# Updated weights: [ -1.3  -2.1  -2.1  14.3  -6.5 -19.4  20.3]
# Updated bias: -1.3
# Sample: [78 17 47 86 79 26]
# Prediction: 0, Target: 1
# Updated weights: [ -1.2   5.7  -0.4  19.    2.1 -11.5  22.9]
# Updated bias: -1.2
#
# Epoch 10/10
# Sample: [81  9  8 35 82 31]
# Prediction: 1, Target: 0
# Updated weights: [ -1.3  -2.4  -1.3  18.2  -1.4 -19.7  19.8]
# Updated bias: -1.3
# Sample: [ 8  5 31 49 21 17]
# Prediction: 1, Target: 0
# Updated weights: [ -1.4  -3.2  -1.8  15.1  -6.3 -21.8  18.1]
# Updated bias: -1.4000000000000001
# Sample: [80 47 25 37 27 56]
# Prediction: 1, Target: 0
# Updated weights: [ -1.5 -11.2  -6.5  12.6 -10.  -24.5  12.5]
# Updated bias: -1.5000000000000002
# Sample: [73 63 66 56 34 76]
# Prediction: 0, Target: 1
# Updated weights: [ -1.4  -3.9  -0.2  19.2  -4.4 -21.1  20.1]
# Updated bias: -1.4000000000000001
# Sample: [78 17 47 86 79 26]
# Prediction: 0, Target: 1
# Updated weights: [ -1.3   3.9   1.5  23.9   4.2 -13.2  22.7]
# Updated bias: -1.3
#
# Training accuracy: 50.00%
# Prediction for new marks (Pass=1, Fail=0): 1

# %%
import numpy as np
import pandas as pd
# Load the data
data = pd.read_csv('random_data.csv')
X = data[:, 0]  # Marks
y = data[:, 1]  # Labels (Pass/Fail)

# Normalize the data if necessary
X = X / 100  # Assuming the marks are out of 100

# Initialize weights and bias
weight = 0
bias = 0

# Learning rate
learning_rate = 1

# Step function (threshold function)
def step_function(x):
    return 1 if x > 50 else 0
    # Perceptron prediction using step function
def perceptron_predict(X):
    return step_function((X * weight) + bias)

# Train the perceptron
def train_perceptron(X, y, epochs=1):
    global weight, bias
    for _ in range(epochs):
        for i in range(len(X)):
            prediction = perceptron_predict(X[i])
            # Update the weights and bias if the prediction is incorrect
            if prediction != y[i]:
                weight += learning_rate * y[i]* X[i]
                bias += learning_rate * y[i]

# Train the perceptron
train_perceptron(X, y)

# Testing the perceptron
predictions = [perceptron_predict(x) for x in X]
accuracy = np.mean(predictions == y)
print(f'Accuracy: {accuracy * 100:.2f}%')
print(weight)
print(bias)
